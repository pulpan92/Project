# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import skimage.transform

class AlexNet(nn.Module):
    def __init__(self, class_num):
        super(AlexNet, self).__init__()
        self.feature0 = nn.Conv2d(3, 64, kernel_size = (11, 11), stride = 4, padding = 5)
        self.feature1 = nn.ReLU(inplace = True)
        self.feature2 = nn.MaxPool2d(kernel_size = 3, stride = 2)
        self.feature3 = nn.Conv2d(64, 192, kernel_size=5, padding=2)
        self.feature4 = nn.ReLU(inplace=True)
        self.feature5 = nn.MaxPool2d(kernel_size=3, stride=2)
        self.feature6 = nn.ReLU(inplace=True)
        self.feature7 = nn.Conv2d(192, 384, kernel_size=3, padding=2)
        self.feature8 = nn.ReLU(inplace=True)
        self.feature9 = nn.Conv2d(384, 256, kernel_size=3, padding=2)
        self.feature10 = nn.ReLU(inplace=True)
        self.feature11 = nn.Conv2d(256, 256, kernel_size=3, padding=2)
        self.feature12 = nn.ReLU(inplace=True)
        self.feature13 = nn.MaxPool2d(kernel_size=3, stride=2)
        
        
        
def main():
    AN = AlexNet(10)
    print("test")
    
if __name__ == '__main__':
    main()
# class AlexNet(nn.Module):
#     def __init__(self, class_num):
#         super(AlexNet, self).__init__()
#         self.feature_network = nn.Sequential(
#             nn.Conv2d(3, 64, kernel_size = (11, 11), stride = 4, padding = 5),
#             nn.ReLU(inplace = True),
#             nn.MaxPool2d(kernel_size = 3, stride = 2),
#             nn.Conv2d(64, 192, kernel_size=5, padding=2),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=3, stride=2),
#             nn.Conv2d(192, 384, kernel_size=3, padding=2),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(384, 256, kernel_size=3, padding=2),
#             nn.ReLU(inplace=True),
#             nn.Conv2d(256, 256, kernel_size=3, padding=2),
#             nn.ReLU(inplace=True),
#             nn.MaxPool2d(kernel_size=3, stride=2)
#         )
        
#         self.classifier_network = nn.Sequential(
#             nn.Dropout(),
#             nn.Linear(256 * 3 * 3, class_num)
#         )
        
        
#     def forward(self, x):
#         avg = nn.AvgPool2d(3)
#         f1 = self.feature_network(x)
#         f2 = avg(f1)
# #         print('[] f2 size: ', f2.size())
#         f3 = f2.view(-1, 256 * 3 * 3)
#         result = self.classifier_network(f3)
        
#         return result, f1
